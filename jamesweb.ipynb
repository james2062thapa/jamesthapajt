# %%
jamesthapajt-website/
├── index.html
└── style.css

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>James Thapa JT</title>
  <link rel="stylesheet" href="style.css" />
</head>
<body>
  <header>
    <div class="container">
      <h1>James Thapa JT</h1>
      <p>Welcome to my personal website</p>
    </div>
  </header>

  <main class="container">
    <section id="about">
      <h2>About Me</h2>
      <p>Hello! I'm James Thapa JT. I'm passionate about technology, creativity, and learning new skills every day. This is my digital space where I showcase my work and connect with others.</p>
    </section>

    <section id="projects">
      <h2>Projects</h2>
      <ul>
        <li><strong>Personal Portfolio</strong> – A site about me (this one!)</li>
        <li><strong>Mini Web Apps</strong> – JavaScript games and utilities</li>
      </ul>
    </section>

    <section id="contact">
      <h2>Contact</h2>
      <p>Email: <a href="mailto:jamesthapajt@example.com">jamesthapajt@example.com</a></p>
      <p>LinkedIn: <a href="#">Your LinkedIn Profile</a></p>
    </section>
  </main>

  <footer>
    <p>© 2025 James Thapa JT. All rights reserved.</p>
  </footer>
</body>
</html>

# %%
/* Reset & base styles */
* {
  margin: 0;
  padding: 0;
  box-sizing: border-box;
}
body {
  font-family: 'Segoe UI', sans-serif;
  background-color: #f4f4f4;
  color: #333;
  line-height: 1.6;
}

/* Container layout */
.container {
  width: 90%;
  max-width: 800px;
  margin: auto;
  padding: 20px;
}

/* Header styling */
header {
  background-color: #333;
  color: #fff;
  padding: 40px 0;
  text-align: center;
}
header h1 {
  margin-bottom: 10px;
}

/* Section styling */
section {
  margin: 40px 0;
}
h2 {
  margin-bottom: 15px;
  color: #222;
}
ul {
  list-style-type: square;
  padding-left: 20px;
}

/* Footer styling */
footer {
  text-align: center;
  padding: 20px 0;
  background-color: #eee;
  margin-top: 40px;
}
